# %%
import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import re
import os

import tensorflow as tf 

from tensorflow import keras
from tensorflow.keras import layers

# %%
dataset_path = keras.utils.get_file("boston_data.data", "http://lib.stat.cmu.edu/datasets/boston")
dataset_path
# Out:
# 'C:\\Users\\over-\\.keras\\datasets\\boston_data.data'

# %%
col_names = [ 'c{0:02d}'.format(i) for i in range(14) ]

path = "C:\\Users\\over-\\.keras\\datasets\\boston_data.data"

raw_dataset = pd.read_csv(path, sep=' ', names=col_names, 
                          skipinitialspace=True)

dataset = raw_dataset

# %%
dataset
# Out:
#             c00    c01    c02  c03    c04    c05   c06     c07  c08    c09  \
# 0       0.00632  18.00   2.31  0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1     396.90000   4.98  24.00  NaN    NaN    NaN   NaN     NaN  NaN    NaN
# 2       0.02731   0.00   7.07  0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 3     396.90000   9.14  21.60  NaN    NaN    NaN   NaN     NaN  NaN    NaN
# 4       0.02729   0.00   7.07  0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# ...         ...    ...    ...  ...    ...    ...   ...     ...  ...    ...
# 1007  396.90000   5.64  23.90  NaN    NaN    NaN   NaN     NaN  NaN    NaN
# 1008    0.10959   0.00  11.93  0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 1009  393.45000   6.48  22.00  NaN    NaN    NaN   NaN     NaN  NaN    NaN
# 1010    0.04741   0.00  11.93  0.0  0.573  6.030  80.8  2.5050  1.0  273.0
# 1011  396.90000   7.88  11.90  NaN    NaN    NaN   NaN     NaN  NaN    NaN
#
#        c10  c11  c12  c13
# 0     15.3  NaN  NaN  NaN
# ...
